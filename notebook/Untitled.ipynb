# %%
import Magics.macro as magics

magics.plot(magics.mcoast())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-278566a0c059> in <module>()
# ----> 1 import Magics.macro as magics
#       2
#       3 magics.plot(magics.mcoast())
#
# ImportError: No module named 'Magics'
