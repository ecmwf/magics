# %%
import Magics.macro as magics

dir(magics)
# Out:
# ['Action',
#  'Context',
#  'Image',
#  'LOCK',
#  'Magics',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '_execute',
#  '_plot',
#  'actions',
#  'context',
#  'examine',
#  'make_action',
#  'maxis',
#  'mboxplot',
#  'mcoast',
#  'mcont',
#  'mepsbar',
#  'mepscloud',
#  'mepsgraph',
#  'mepsinput',
#  'mepslight',
#  'mepsplumes',
#  'mepsshading',
#  'mepswave',
#  'mepswind',
#  'mgeo',
#  'mgeojson',
#  'mgraph',
#  'mgrib',
#  'mimport',
#  'minput',
#  'mlegend',
#  'mline',
#  'mmap',
#  'mmapgen',
#  'mmetbufr',
#  'mmetgraph',
#  'mnetcdf',
#  'mobs',
#  'msymb',
#  'mtable',
#  'mtaylor',
#  'mtephi',
#  'mtext',
#  'mwind',
#  'mwrepjson',
#  'numpy',
#  'odb_filter',
#  'odb_geopoints',
#  'odb_geovectors',
#  'odb_xypoints',
#  'odb_xyvectors',
#  'os',
#  'output',
#  'page',
#  'paxis',
#  'pboxplot',
#  'pcoast',
#  'pcont',
#  'pgeo',
#  'pgraph',
#  'pgrib',
#  'pimport',
#  'pinput',
#  'plegend',
#  'pline',
#  'plot',
#  'pmap',
#  'pmapgen',
#  'pnetcdf',
#  'pobs',
#  'psymb',
#  'ptext',
#  'pwind',
#  'sys',
#  'tempfile',
#  'threading',
#  'tofortran',
#  'tohtml',
#  'tomv4']

# %%
from Magics import macro

# %%
x = macro.output(output_formats=["png"],
                          output_name_first_page_number='off',
                          output_name="x")
macro.plot(x, macro.mcoast())

# %%
import maps
from Magics import macro
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-26013ff84beb> in <module>()
# ----> 1 import maps
#       2 from Magics import macro
#       3
#       4
#
# ImportError: No module named maps

# %%
maps.myplot(macro.mcoast(map_coastline_land_shade = "on",
  map_coastline_land_shade_colour = "rgb(0.65,0.32,0.32)"), 
            macro.mcoast(
  map_coastline_colour = "red",
  map_coastline_thickness = 10
))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-278f5316ab0c> in <module>()
# ----> 1 maps.myplot(macro.mcoast(map_coastline_land_shade = "on",
#       2   map_coastline_land_shade_colour = "rgb(0.65,0.32,0.32)"),
#       3             macro.mcoast(
#       4   map_coastline_colour = "red",
#       5   map_coastline_thickness = 10
#
# NameError: name 'maps' is not defined

# %%
maps.plot("data.grib")
