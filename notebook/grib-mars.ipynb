# %%
from ecmwfapi import ECMWFService
from Magics.toolbox import graph

# %%
target = "2t.grib"
print target
# Out:
# 2t.grib

# %% [markdown]
# I get the data

# %%
key = {
        "url"   : "https://api.ecmwf.int/v1",
        "key"   : "83253855c912864513eb33f5fb1de322",
        "email" : "Sylvie.Lamy-Thepaut@ecmwf.int"
        }

request = {
                "dataset" : "od",
                "class"   : "od",
                "date"    : "2016-10-31",
                "levtype" : "sfc",
                "param"   : "167.128",
                "step"    : 6,
                "type"    : "fc",
                "time"    : 0,
                "grid"    : [0.5,0.5]
        }

mars = ECMWFService("mars", **key)           
mars.execute(request, target)
# Out:
# 2016-11-01 12:06:29 ECMWF API python library 1.4.1
# 2016-11-01 12:06:29 ECMWF API at https://api.ecmwf.int/v1
# 2016-11-01 12:06:29 Welcome Sylvie Lamy-Thepaut
# 2016-11-01 12:06:29 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2016-11-01 12:06:29 In case of delays, please check the MARS service activity page http://apps.ecmwf.int/mars-activity/
# 2016-11-01 12:06:29 Request submitted
# 2016-11-01 12:06:29 Request id: 5818854561685079091034ce
# 2016-11-01 12:06:29 Request is queued
# Error contacting the WebAPI, retrying in 60 seconds ...
# Calling '['nice', 'mars', '/tmp/tmp-_marsU3uKUi.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20161101.121253 - Welcome to MARS with grib_api and ODB
# mars - INFO   - 20161101.121253 - MARS Client build stamp: 20160429081542
# mars - INFO   - 20161101.121253 - MARS Client version: 6.15.2
# mars - INFO   - 20161101.121253 - EMOSLIB version: 441
# mars - INFO   - 20161101.121253 - Using grib_api version 1.15.0
# mars - INFO   - 20161101.121253 - Using odb_api version: 0.11.0 (file format version: 0.5)
# mars - INFO   - 20161101.121253 - Maximum retrieval size is 20.00 G
# retrieve,class=od,dataset=od,date=2016-10-31,expect=any,grid=0.5/0.5,levtype=sfc,padding=0,param=167.128,step=6,time=0,type=fcmars - INFO   - 20161101.121253 - Automatic split by date is on
#
# mars - INFO   - 20161101.121253 - Processing request 1
#
# RETRIEVE,
#     DATASET    = od,
#     CLASS      = OD,
#     TYPE       = FC,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = GG,
#     LEVTYPE    = SFC,
#     PARAM      = 167.128,
#     TIME       = 0000,
#     STEP       = 6,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 0.5/0.5,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 20161031
#
# mars - INFO   - 20161101.121253 - Web API request id: 5818854561685079091034ce
# mars - INFO   - 20161101.121253 - Requesting any number of fields (request describes 1)
# mars - INFO   - 20161101.121253 - Calling mars on 'marsod', callback on 32872
# mars - INFO   - 20161101.121253 - Server task is 485 [marsod]
# mars - INFO   - 20161101.121253 - Request cost: 1 field, 12.5929 Mbytes online, nodes: mvr07 [marsod]
# mars - INFO   - 20161101.121253 - Transfering 13204588 bytes
# mars - INFO   - 20161101.121253 - 1 field retrieved from 'marsod'
# mars - INFO   - 20161101.121253 - 1 field has been interpolated
# mars - INFO   - 20161101.121253 - Request time:  wall: 1 sec
# mars - INFO   - 20161101.121253 -   Read from network: 12.59 Mbyte(s) in < 1 sec [69.55 Mbyte/sec]
# mars - INFO   - 20161101.121253 -   Writing to target file: 507.76 Kbyte(s) in < 1 sec [866.89 Mbyte/sec]
# mars - INFO   - 20161101.121253 - No errors reported
# Process '['nice', 'mars', '/tmp/tmp-_marsU3uKUi.req']' finished
# 2016-11-01 13:36:44 Request is complete
# 2016-11-01 13:36:44 Transfering 507.762 Kbytes into 2t.grib
# 2016-11-01 13:36:44 From http://stream.ecmwf.int/data/atls02/data/data01/scratch/_mars-atls02-95e2cf679cd58ee9b4db4dd119a05a8d-rUT1A7.grib
# 2016-11-01 13:36:44 Transfer rate 3.25178 Mbytes/s
# 2016-11-01 13:36:45 Done.

# %%
#Setting the coordinates of the geographical area
projection = mmap(subpage_map_projection = 'cylindrical',
                  subpage_lower_left_latitude= 34.,
                  subpage_lower_left_longitude= -40.,
                  subpage_upper_right_latitude= 60.,
                  subpage_upper_right_longitude= 24.)

grib = mgrib(grib_input_file_name=target)

contour = mcont(
    contour_automatic_setting="ecchart",
    legend="on"
)

title = mtext()
legend = mlegend( legend_display_type = "continuous")

plot(projection, grib, contour, title, mcoast(), legend)
