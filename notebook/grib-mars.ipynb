# %%
from ecmwfapi import ECMWFService

# %%
target = "2t.grib"
print target
# Out:
# 2t.grib

# %% [markdown]
# I get the data

# %%
key = {
        "url"   : "https://api.ecmwf.int/v1",
        "key"   : "83253855c912864513eb33f5fb1de322",
        "email" : "Sylvie.Lamy-Thepaut@ecmwf.int"
        }

request = {
                "dataset" : "od",
                "class"   : "od",
                "date"    : "-1",
                "levtype" : "sfc",
                "param"   : "167.128",
                "step"    : 6,
                "type"    : "fc",
                "time"    : 0,
                "grid"    : [0.5,0.5]
        }

mars = ECMWFService("mars", **key)           
mars.execute(request, target)
# Out:
# 2017-01-04 09:55:40 ECMWF API python library 1.4.1
# 2017-01-04 09:55:40 ECMWF API at https://api.ecmwf.int/v1
# 2017-01-04 09:55:40 Welcome Sylvie Lamy-Thepaut
# 2017-01-04 09:55:40 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2017-01-04 09:55:40 In case of delays, please check the MARS service activity page http://apps.ecmwf.int/mars-activity/
# 2017-01-04 09:55:40 Request submitted
# 2017-01-04 09:55:40 Request id: 586cc69cf952b16e769fba61
# 2017-01-04 09:55:40 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_marsOiMtMr.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20170104.095541 - Welcome to MARS with grib_api and ODB
# mars - INFO   - 20170104.095541 - MARS Client build stamp: 20160429081542
# mars - INFO   - 20170104.095541 - MARS Client version: 6.15.2
# mars - INFO   - 20170104.095541 - EMOSLIB version: 441
# mars - INFO   - 20170104.095541 - Using grib_api version 1.15.0
# mars - INFO   - 20170104.095541 - Using odb_api version: 0.11.0 (file format version: 0.5)
# mars - INFO   - 20170104.095541 - Maximum retrieval size is 20.00 G
# retrieve,class=od,dataset=od,date=-1,expect=any,grid=0.5/0.5,levtype=sfc,padding=0,param=167.128,step=6,time=0,type=fcmars - INFO   - 20170104.095541 - Automatic split by date is on
#
# mars - INFO   - 20170104.095541 - Processing request 1
#
# RETRIEVE,
#     DATASET    = od,
#     CLASS      = OD,
#     TYPE       = FC,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = GG,
#     LEVTYPE    = SFC,
#     PARAM      = 167.128,
#     TIME       = 0000,
#     STEP       = 6,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 0.5/0.5,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 20170103
#
# mars - INFO   - 20170104.095541 - Web API request id: 586cc69cf952b16e769fba61
# mars - INFO   - 20170104.095541 - Requesting any number of fields (request describes 1)
# mars - INFO   - 20170104.095541 - Calling mars on 'marsod', callback on 46482
# mars - INFO   - 20170104.095541 - Server task is 0 [marsod]
# mars - INFO   - 20170104.095541 - Request cost: 1 field, 12.5929 Mbytes online, nodes: mvr04 [marsod]
# mars - INFO   - 20170104.095541 - Transfering 13204588 bytes
# mars - INFO   - 20170104.095542 - 1 field retrieved from 'marsod'
# mars - INFO   - 20170104.095542 - 1 field has been interpolated
# mars - INFO   - 20170104.095542 -   Read from network: 12.59 Mbyte(s) in < 1 sec [146.79 Mbyte/sec]
# mars - INFO   - 20170104.095542 -   Writing to target file: 507.76 Kbyte(s) in < 1 sec [820.96 Mbyte/sec]
# mars - INFO   - 20170104.095542 - No errors reported
# Process '['nice', 'mars', '/tmp/tmp-_marsOiMtMr.req']' finished
# 2017-01-04 09:55:42 Request is complete
# 2017-01-04 09:55:42 Transfering 507.762 Kbytes into 2t.grib
# 2017-01-04 09:55:42 From http://stream.ecmwf.int/data/atls09/data/data01/scratch/_mars-atls09-95e2cf679cd58ee9b4db4dd119a05a8d-B4rsB1.grib
# 2017-01-04 09:55:42 Transfer rate 2.9171 Mbytes/s
# 2017-01-04 09:55:43 Done.

# %%
import Magics.macro as magics
#Setting the coordinates of the geographical area
projection = magics.mmap(subpage_map_projection = 'cylindrical',
                  subpage_lower_left_latitude= 34.,
                  subpage_lower_left_longitude= -40.,
                  subpage_upper_right_latitude= 60.,
                  subpage_upper_right_longitude= 24.)

grib = magics.mgrib(grib_input_file_name=target)

contour = magics.mcont(
    contour_automatic_setting="ecchart",
    legend="on"
)

title = magics.mtext()
legend = magics.mlegend( legend_display_type = "continuous")

magics.plot(projection, grib, contour, title, magics.mcoast(), legend)
