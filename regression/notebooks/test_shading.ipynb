# %% [markdown]
# # Testing shading

# %% [markdown]
# ### Import Magics and define non Contour paramters

# %%
import Magics.macro as magics

projection = magics.mmap(
    subpage_map_library_area = "on",
    subpage_map_area_name    = "europe",
    page_id_line             = "off"
)

zoomed_projection = magics.mmap(
    subpage_map_library_area = "on",
    subpage_map_area_name    = "south_west_europe",
    page_id_line             = "off"
)

coast = magics.mcoast()

black_coast = magics.mcoast(
    map_coastline_colour            = "grey",
    map_coastline_resolution        = "medium",
    map_coastline_thickness         = 2,
    map_coastline_land_shade        = "on",
    map_coastline_land_shade_colour = "RGB(0.25,0.25,0.25)",
    map_coastline_sea_shade         = "on",
    map_coastline_sea_shade_colour  = "black",
    map_grid_line_style             = "dash",
    map_grid_colour                 = "grey",
)


legend = magics.mlegend(legend_display_type   = 'continuous')

# Different meteorological parameter we will plot in this notebook
temperature   = magics.mgrib(grib_input_file_name   = "t850.grib")
geopotential  = magics.mgrib(grib_input_file_name   = "z500.grib")
precipitation = magics.mgrib(grib_input_file_name   = "total_precipitation.grib")
sat_ir        = magics.mgrib(grib_input_file_name   = "ssd.grib",
                             grib_automatic_scaling = "off")
ptype         = magics.mgrib(grib_input_file_name   = "ptype.grib")

# %% [markdown]
# Default shade

# %%
t_cont = magics.mcont(
    contour       = "off",
    contour_shade = "on"
)

magics.plot(projection, temperature, t_cont, coast)

# %% [markdown]
# ### Simple shading

# %%
t_cont = magics.mcont( 
    contour                        = "off",
    contour_level_selection_type   = "interval",
    contour_interval               = 2.00,
    contour_shade                  = "on",
    contour_shade_method           = "area_fill",
    contour_shade_min_level        = -28,
    contour_shade_max_level        = 24,
    contour_shade_colour_method    = "calculate",
    contour_shade_colour_direction = "clockwise",
    contour_label                  = "off",
    contour_shade_max_level_colour = "red",
    contour_shade_min_level_colour = "blue",
    legend                         = "on"
)
       
magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# ### Simple shading
# anti_clockwise, label = on

# %%
t_cont = magics.mcont( 
    contour                        = "off",
    contour_level_selection_type   = "interval",
    contour_interval               = 4.00,
    contour_shade                  = "on",
    contour_shade_method           = "area_fill",
    contour_shade_min_level        = -28,
    contour_shade_max_level        = 24,
    contour_shade_colour_method    = "calculate",
    contour_shade_colour_direction = "anti_clockwise",
    contour_label                  = "on",
    contour_shade_max_level_colour = "red",
    contour_shade_min_level_colour = "blue",
    legend                         = "on"
)
       
magics.plot(projection, temperature, t_cont, coast, legend)

# %%
t_cont = magics.mcont( 
    contour                        = "off",
    contour_level_selection_type   = "interval",
    contour_interval               = 3.00,
    contour_shade                  = "on",
    contour_shade_method           = "area_fill",
    contour_shade_min_level        = -28,
    contour_shade_max_level        = 24,
    contour_shade_colour_method    = "calculate",
    contour_shade_colour_direction = "anti_clockwise",
    contour_label                  = "on",
    contour_shade_max_level_colour = "orange",
    contour_shade_min_level_colour = "cyan",
    contour_interpolation_floor    = -28,
    contour_interpolation_ceiling  = 23.9,
    legend                         = "on"
)
       
magics.plot(projection, temperature, t_cont, coast, legend)

# %%
t_cont = magics.mcont( 
    contour                        = "off",
    contour_level_selection_type   = "interval",
    contour_interval               = 3.00,
    contour_shade                  = "on",
    contour_shade_method           = "area_fill",
    contour_shade_min_level        = -28,
    contour_shade_max_level        = 24,
    contour_shade_colour_method    = "calculate",
    contour_shade_colour_direction = "anti_clockwise",
    contour_label                  = "on",
    contour_shade_max_level_colour = "orange",
    contour_shade_min_level_colour = "cyan",
    contour_interpolation_floor    = -28,
    contour_interpolation_ceiling  = 23.9,
    legend                         = "on"
)
       
magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# Gradients, contour_level_selection_type = level_list

# %%
t_cont = magics.mcont(
    legend                            = "on",
    contour                           = "off",
    contour_level_selection_type      = "level_list",
    contour_level_list                = [-30.,-20.,0.,20.,30.],
    contour_gradients_step_list       = [5,10,10,5],
    contour_label                     = "off",
    contour_shade                     = "on",
    contour_shade_colour_method       = "gradients",
    contour_gradients_technique       = "rgb",
    contour_shade_method              = "area_fill",
    contour_gradients_colour_list     = ["RGB(0.01961,0.251,0.4157)","greenish_blue","white",
                                         "orangish_red","RGB(0.3756,0.06648,0.05582)"],
    contour_gradients_waypoint_method = "both")

magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# Gradients, contour_level_selection_type = interval

# %%
t_cont = magics.mcont(
    legend                            = "on",
    contour                           = "off",
    contour_level_selection_type      = "interval",
    contour_interval                  = 10,
    contour_gradients_step_list       = [5],
    contour_shade_min_level           = -20,
    contour_shade_max_level           = 20,
    contour_label                     = "off",
    contour_shade                     = "on",
    contour_shade_colour_method       = "gradients",
    contour_gradients_technique       = "rgb",
    contour_shade_method              = "area_fill",
    contour_gradients_colour_list     = ["RGB(0.01961,0.251,0.4157)","greenish_blue","white",
                                         "orangish_red","RGB(0.3756,0.06648,0.05582)"],
    contour_gradients_waypoint_method = "right")

magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# Gradients, contour_level_selection_type = interval, contour_gradients_technique       = "hcl",

# %%
t_cont = magics.mcont(
    legend                            = "on",
    contour                           = "off",
    contour_level_selection_type      = "interval",
    contour_interval                  = 10,
    contour_gradients_step_list       = [5],
    contour_shade_min_level           = -20,
    contour_shade_max_level           = 20,
    contour_label                     = "off",
    contour_shade                     = "on",
    contour_shade_colour_method       = "gradients",
    contour_gradients_technique       = "hcl",
    contour_shade_method              = "area_fill",
    contour_gradients_colour_list     = ["RGB(0.01961,0.251,0.4157)","greenish_blue","white",
                                         "orangish_red","RGB(0.3756,0.06648,0.05582)"],
    contour_gradients_waypoint_method = "ignore")

magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# Gradients, contour_level_selection_type = interval, contour_gradients_technique = "hsl",
# contour_gradients_technique_direction = 'anti_clockwise'

# %%
t_cont = magics.mcont(
    legend                            = "on",
    contour                           = "off",
    contour_level_selection_type      = "count",
    contour_level_count               = 6,
    contour_gradients_step_list       = [10],
    contour_shade_min_level           = -28,
    contour_shade_max_level           = 26,
    contour_label                     = "off",
    contour_shade                     = "on",
    contour_shade_colour_method       = "gradients",
    CONTOUR_GRADIENTS_TECHNIQUE_DIRECTION = "anti_CLOCKWISE",
    contour_gradients_technique       = "hsl",
    contour_shade_method              = "area_fill",
    contour_gradients_colour_list     = ["RGB(0.01961,0.251,0.4157)","greenish_blue","white",
                                         "red","RGB(0.3756,0.06648,0.05582)"],
    contour_gradients_waypoint_method = "left")

magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# contour_shade_colour_methd = list, contour_level_selection_type = interval

# %%
t_cont = magics.mcont(
    contour_level_selection_type = "interval",
    contour_interval             = 2.00,
    contour_shade_method         = "area_fill",
    contour_shade                = "on",
    contour_shade_max_level      = 42.00,
    contour_shade_min_level      = -32.00,
    contour_label                = "off",
    legend                       = "on",
    contour                      = "off",
    contour_shade_colour_method  = "list",
    contour_shade_colour_list    = ["rgb(0.3,0.3,0.3)", "rgb(0.4,0.4,0.4)", "rgb(0.5,0.5,0.5)", 
                                    "rgb(0.6,0.6,0.6)", "rgb(0.7,0.7,0.7)","rgb(0.8,0.8,0.8)", 
                                    "rgb(0.35,0,0.6)", "rgb(0.5,0,0.9)", "rgb(0.6,0.2,1)", 
                                    "rgb(0.75,0.4,1)", "rgb(0.85,0.6,1)", "rgb(0,0,0.75)", 
                                    "rgb(0,0,1)", "rgb(0.2,0.4,1)", "rgb(0.4,0.7,1)", 
                                    "rgb(0.6,0.9,1)", "rgb(0,0.55,0.19)", "rgb(0.15,0.75,0.1)", 
                                    "rgb(0.5,0.85,0)", "rgb(0.65,0.95,0)", "rgb(0.8,1,0.2)", 
                                    "rgb(0.65,0.65,0)", "rgb(0.8,0.8,0)", "rgb(0.92,0.92,0)", 
                                    "rgb(1,1,0)", "rgb(1,1,0.6)", "rgb(0.85,0.45,0)", 
                                    "rgb(1,0.5,0)", "rgb(1,0.62,0)", "rgb(1,0.74,0)", 
                                    "rgb(1,0.85,0)", "rgb(0.6,0,0)", "rgb(0.8,0,0)", "rgb(1,0,0)", 
                                    "rgb(1,0.4,0.4)", "rgb(1,0.6,0.6)", "rgb(1,0.75,0.75)"])

magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# Colour list given, not enough colours

# %%
t_cont = magics.mcont(
    contour_level_selection_type = "interval",
    contour_interval             = 2.00,
    contour_shade_method         = "area_fill",
    contour_shade                = "on",
    contour_shade_max_level      = 24.00,
    contour_shade_min_level      = -28.00,
    contour_label                = "off",
    legend                       = "on",
    contour                      = "off",
    contour_shade_colour_method  = "list",
    contour_shade_colour_list    = ["rgb(0.35,0,0.6)", "rgb(0.5,0,0.9)", "rgb(0.6,0.2,1)", 
                                    "rgb(0.75,0.4,1)", "rgb(0.85,0.6,1)", "rgb(0,0,0.75)", 
                                    "rgb(0,0,1)", "rgb(0.2,0.4,1)", "rgb(0.4,0.7,1)", 
                                    "rgb(0.6,0.9,1)", "rgb(0,0.55,0.19)", "rgb(0.15,0.75,0.1)", 
                                    "rgb(0.5,0.85,0)", "rgb(0.65,0.95,0)", "rgb(0.8,1,0.2)", 
                                    "rgb(0.65,0.65,0)", "rgb(0.8,0.8,0)", "rgb(0.92,0.92,0)", 
                                    "rgb(1,1,0)", "rgb(1,1,0.6)", "rgb(0.85,0.45,0)", 
                                    "rgb(1,0.5,0)", "rgb(1,0.62,0)", "rgb(1,0.74,0)"])

magics.plot(projection, temperature, t_cont, coast, legend)

# %% [markdown]
# ### Supplying the list of levels and colours

# %%
tp_cont = magics.mcont(
    contour_level_selection_type   = "level_list",
    contour_level_list             = [0.5, 1, 2, 5, 10, 20, 50, 100, 200, 500],
    contour_shade                  = "on",
    contour_shade_method           = "area_fill",
    contour_shade_colour_method    = "list",
    contour_shade_colour_list      = ['#ffffd9','#edf8b1','#c7e9b4',
                                      '#7fcdbb','#41b6c4','#1d91c0',
                                      '#225ea8','#253494','#081d58'],
    contour                        = "off",
    legend                         = "on"
)

magics.plot(projection, precipitation, tp_cont, coast, legend)

# %% [markdown]
# Level list, colour list, contours on, shade on,

# %%
tp_cont = magics.mcont(
    contour_level_selection_type   = "level_list",
    contour_level_list             = [0.5, 1.,1.5, 2, 5, 10, 15, 20, 25, 30, 35, 40, 50],
    contour_shade                  = "on",
    contour_shade_min_level        = 2,
    contour_shade_method           = "area_fill",
    contour_shade_colour_method    = "list",
    contour_shade_colour_list      = ['#ffffd9','#edf8b1','#c7e9b4',
                                      '#7fcdbb','#41b6c4','#1d91c0',
                                      '#225ea8','#253494','#081d58'],
    contour                        = "on",
    contour_line_colour            = '#7fcdbb',
    contour_highlight              = "on", 
    contour_highlight_frequency    = 3,
    contour_highlight_colour       = '#7fcdbb',
    contour_min_level              = 0,
    legend                         = "on",
    contour_label = 'off'
)

magics.plot(projection, precipitation, tp_cont, coast, legend)

# %% [markdown]
# ### Grid shading

# %%
grid_shading = magics.mcont(
    contour_shade_technique      = "grid_shading",
    contour_shade_colour_method  = "list",
    contour                      = "off",
    contour_level_selection_type = "level_list",
    contour_level_list           = [0.5,1.5,3.5,5.5,6.5,7.5,8.5],
    contour_shade                = "on",
    contour_shade_min_level      = 0.5,
    contour_shade_max_level      = 8.5,
    contour_shade_colour_list    = ["green","red","sky","navy","cyan","orange"],
    legend                       = "on"
)  

magics.plot(projection, black_coast, ptype, grid_shading, legend)

# %% [markdown]
# Grid_shading + gradients

# %%
tp_cont = magics.mcont(
    contour_level_selection_type     = "level_list",
    contour_level_list               = [0., 10, 30, 60, 90],
    contour_shade                    = "on",
    contour_gradients_step_list       = [5,4,5,3],
    contour_shade_technique           = "grid_shading",
    contour_shade_colour_method       = "gradients",
    contour_gradients_technique       = "hcl",
    contour_shade_method              = "area_fill",
    CONTOUR_GRADIENTS_TECHNIQUE_DIRECTION = "ANTI_CLOCKWISE",
    contour_gradients_colour_list     = ["white","greenish_blue",
                                         "orangish_red","RGB(0.3756,0.06648,0.05582)","blue_purple"],
    contour_gradients_waypoint_method = "left",
    contour                        = "on",
    contour_line_colour            = 'black',
    contour_highlight              = "on", 
    contour_highlight_frequency    = 3,
    contour_highlight_colour       = '#7fcdbb',
    contour_min_level              = 0,
    legend                         = "on"
)

magics.plot(zoomed_projection, precipitation, tp_cont, coast, legend)

# %%
grid_shading = magics.mcont(
    contour_shade_technique      = "grid_shading",
    contour_shade_colour_method  = "list",
    contour                      = "off",
    contour_level_selection_type = "level_list",
    contour_level_list           = [0.5,1.5,3.5,5.5,6.5,7.5,8.5],
    contour_shade                = "on",
    contour_shade_min_level      = 0.5,
    contour_shade_max_level      = 8.5,
    contour_shade_colour_list    = ["green","red","sky","navy","cyan","orange"],
    legend                       = "on"
)  



legend_grid = magics.mlegend(
    legend_user_lines         =  ["Rain","Freezing rain", "Snow", "Wet snow", "Sleet", "Ice pellets"],
    legend_box_mode           = "automatic",
    legend_automatic_position = "right",
    legend_text_composition   = "user_text_only",
    legend_text_colour        = "charcoal",   
    legend_text_font_size     = 0.5)

magics.plot(zoomed_projection, black_coast, ptype, grid_shading, legend_grid)

# %% [markdown]
# ### Marker shading
#
# Since we are already plotting precipitation type, we might want appropriate symbol for each precipitation type. Magics has built in collection of meteorological symbols and all you have to do is give it WMO code. Full list of WMO codes and descriptions for present/past weather, sky cover, pressure tendency and clouds you can find [on Wikipedia](https://commons.wikimedia.org/wiki/Weather_map "Weather map symbols").
#
# |**marker type** | names |
# |-----------------|
# | present weather | ww_00,.., ww_99  |
# | past weather | W_0,.., W_9 |
# | low clouds | CL_1,.., CL_9 |
# | medium clouds | CM_1,.., CM_9 |
# | high clouds | CH_1,.., CH_9 |
# | type of cloud| C_0,.., C_9|
# | total amount all clouds | N_0,..,N9 |
# | atmospheric pressure tendency | a_0,..,a_9 |
#
# Let's also zoom map a little bit so we can see markers better.

# %%
marker_shading = magics.mcont(
        contour                         = "off",
        legend                          = "off",
        contour_level_list              = [1.00,3.00,5.00,6.00,7.00,8.00,9.00],
        contour_level_selection_type    = "level_list",
        contour_shade                   = "on",
        contour_shade_colour_table      = ["green","red","blue","navy","turquoise","orange"],
        contour_shade_height_table      = [1.0],
        contour_shade_marker_table_type = "name",
        contour_shade_marker_name_table = ["ww_60","ww_67","ww_70","ww_68","ww_69","ww_79"],
        contour_shade_technique         = "marker") 

zoomed_projection = magics.mmap(
    subpage_clipping  = 'on',
    subpage_lower_left_latitude    = 47.,
    subpage_lower_left_longitude   = 25.0,
    subpage_map_projection         = 'polar_stereographic',
    subpage_upper_right_latitude   = 52.,
    subpage_upper_right_longitude  = 33.5,
    subpage_map_vertical_longitude = 29.0,
    subpage_map_area_definition    = 'corners',
    page_id_line             = "off"

)

magics.plot(zoomed_projection, black_coast, ptype, marker_shading)

# %%
marker_shading = magics.mcont(
        contour                         = "off",
        legend                          = "off",
        contour_level_list              = [1.00,2.00,3.00,4.00,5.00,6.00,7.00,8.00,9.00],
        contour_level_selection_type    = "level_list",
        contour_shade                   = "on",
        contour_shade_colour_table      = ["white","cyan","orange","rose","turquoise","pink","green","yellow"],
        contour_shade_height_table      = [0.3,0.4,0.4,0.5,0.6,0.8],
        contour_shade_marker_table_type = "name",
        contour_shade_marker_name_table = ["N_1","N_2","N_3","N_4","N_5","N_6","N_7","N_8"],
        contour_shade_technique         = "marker") 

zoomed_projection = magics.mmap(
    subpage_clipping  = 'on',
    subpage_lower_left_latitude    = 47.,
    subpage_lower_left_longitude   = 23.0,
    subpage_map_projection         = 'polar_stereographic',
    subpage_upper_right_latitude   = 55.,
    subpage_upper_right_longitude  = 40,
    subpage_map_vertical_longitude = 29.0,
    subpage_map_area_definition    = 'corners',
    page_id_line             = "off"

)

magics.plot(zoomed_projection, black_coast, ptype, marker_shading)

# %% [markdown]
# ### Cell shading
#
# Cell shading is another contour_shade_technique. If we don't want to do full grid shading, but to group them in cells, we can use cell_shading technique.

# %%
ir_clouds = magics.mcont(
    contour_shade_colour_direction   = "clockwise",
    contour_shade_min_level_colour   = "white",
    contour_shade_max_level_colour   = "black",
    contour_shade_colour_method      = "calculate",
    legend                           = "off",
    contour                          = "off",
    contour_level_selection_type     = "level_list",
    contour_level_list               = [170.,199.,201.,203.,205.,207,208,209,210,
                                        211,212,213,214,215,216,217,218,219,220,
                                        221,222,223,224,225,226,227,228,229,230,
                                        231,232,233,234,235,236,237,238,239,240,
                                        241,242,243,244,245,246,247,249,251,253,
                                        255,257,259,261,263,265,267,269,271,273,
                                        275,277,279,281,283,285,287,289,291,293,
                                        295,297,299,301,303,305,307,310,315,320,350],
    contour_shade                    = "on",
    contour_shade_technique          = "cell_shading",
    contour_shade_cell_resolution    = 80
    )

magics.plot(projection, sat_ir, ir_clouds, coast)

# %%
ir_clouds = magics.mcont(
    contour_shade_colour_direction   = "anti_clockwise",
    contour_shade_min_level_colour   = "evergreen",
    contour_shade_max_level_colour   = "white",
    contour_shade_min_level          = 200,
    contour_shade_max_level          = 300,
    contour_shade_colour_method      = "calculate",
    legend                           = "on",
    contour                          = "off",
    contour_level_selection_type     = "count",
    contour_level_count              = 20,
    contour_shade                    = "on",
    contour_shade_technique          = "cell_shading",
    contour_shade_cell_resolution    = 20
    )

magics.plot(projection, sat_ir, ir_clouds, coast, legend)
