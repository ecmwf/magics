# %% [markdown]
# # Test different Contouring options

# %%
import Magics.macro as magics

projection = magics.mmap(
    subpage_map_library_area = "on",
    subpage_map_area_name    = "central_europe",
    page_id_line             = "off"
)

coast = magics.mcoast()

legend = magics.mlegend(legend_display_type   = 'continuous')

# Different meteorological parameters we will plot in this notebook
temperature   = magics.mgrib(grib_input_file_name = "t850.grib")
geopotential  = magics.mgrib(grib_input_file_name = "z500.grib")
precipitation = magics.mgrib(grib_input_file_name = "total_precipitation.grib")

from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Default

# %%
z_cont = magics.mcont(contour_threads = 1)

magics.plot(projection, geopotential, z_cont, coast)

# %% [markdown]
# ### Simple contouring...

# %%
z_cont = magics.mcont( 
    contour_line_colour         = "navy",
    contour_line_thickness      = 2,
    contour_highlight_colour    = "navy",
    contour_highlight_thickness = 6,
    legend                      = "off",
    contour_threads              = 1
   
    )

magics.plot(projection, geopotential, z_cont, coast)

# %% [markdown]
# dash, different colour for highlight, interval

# %%
z_cont = magics.mcont(
    contour_level_selection_type = "interval",
    contour_reference_level      = 500,
    contour_interval             = 4.00,
    contour_line_style           = "dash",
    contour_line_colour          = "evergreen",
    contour_line_thickness       = 3,
    contour_label                = "on",
    contour_threads              = 1,
    contour_label_colour         = "contour_line_colour",
    contour_label_height         = 0.50,
    contour_highlight_frequency  = 5,
    contour_highlight_colour     = "navy",
    contour_highlight_thickness  = 4,
    legend                       = "on"
)

magics.plot(projection, geopotential, z_cont, coast)

# %%
z_cont = magics.mcont(
    contour_level_selection_type = "interval",
    contour_reference_level      = 500,
    contour_interval             = 4.00,
    contour_line_style           = "dash",
    contour_line_colour          = "evergreen",
    contour_line_thickness       = 3,
    contour_threads              = 1,
    contour_label                = "on",
    contour_label_colour         = "contour_line_colour",
    contour_label_type           = "text",
    contour_label_text           = "some text",
    contour_label_height         = 0.50,
    contour_highlight_frequency  = 2,
    contour_highlight_colour     = "navy",
    contour_highlight_thickness  = 2,
    legend                       = "on"
)

magics.plot(projection, geopotential, z_cont, coast)

# %% [markdown]
# ### Displaying the grid values
#
# In this example we will see how to display grid values together with isolines. Instead of value we could also plot a marker, or both.
#
# For the isolines, we will use **'level_list'** as a type, and then provide customized list.

# %%
tp_cont = magics.mcont(
    contour_grid_value_plot          = "on",
    contour_grid_value_height        = 0.50,
    contour_grid_value_plot_type     = "both",
    contour_grid_value_format        = "(i4)",
    contour_grid_value_colour        = "black",
    contour_grid_value_marker_height = 0.5,
    contour_grid_value_marker_colour = "evergreen",
    contour_grid_value_lon_frequency = 3,
    contour_grid_value_lat_frequency = 3,
    contour_highlight                = "off",
    contour_line_colour              = "grey",
    contour_line_thickness           = 2,
    contour_level_selection_type     = "level_list",
    contour_level_list               = [0.5, 2, 4, 10, 20, 30, 50, 100, 250],
    contour_label                    = "off",
    legend                           = "off"
)

magics.plot(projection, precipitation, tp_cont, coast)

# %%
projection = magics.mmap(
    subpage_map_library_area = "on",
    subpage_map_area_name    = "central_europe",
    subpage_clipping         = "on",
    page_id_line             = "off"
)

tp_cont = magics.mcont(
    contour_grid_value_plot          = "on",
    contour_grid_value_height        = 0.50,
    contour_grid_value_plot_type     = "both",
    contour_grid_value_format        = "(f4.2)",
    contour_grid_value_colour        = "charcoal",
    contour_grid_value_marker_height = 0.8,
    contour_grid_value_marker_colour = "red",
    contour_grid_value_lon_frequency = 2,
    contour_grid_value_lat_frequency = 2,
    contour_grid_value_vertical_align = "bottom",
    contour_grid_value_justification = 'left',
    contour_grid_value_marker_index  = 15,
    contour_highlight                = "off",
    contour_line_colour              = "beige",
    contour_line_thickness           = 2,
    contour_level_selection_type     = "level_list",
    contour_level_list               = [0.5, 2, 4, 10, 20, 30, 50, 100, 250],
    contour_label                    = "off",
    legend                           = "off"
)

magics.plot(projection, precipitation, tp_cont, coast)

# %% [markdown]
# ### Rainbow method to colour the isolines (computing a range of colours)

# %%
t_cont = magics.mcont(
    contour_label                                = "on",
    contour_label_height                         = 0.5,
    legend                                       = "on",
    contour_level_selection_type                 = "interval",
    contour_interval                             = 1.00,
    contour_line_thickness                       = 3,
    contour_line_colour_rainbow                  = "on",
    contour_line_colour_rainbow_method           = "calculate",
    contour_line_colour_rainbow_max_level_colour = "evergreen",
    contour_line_colour_rainbow_min_level_colour = "turquoise",
    contour_line_colour_rainbow_direction        = "anti_clockwise",
    contour_line_thickness_rainbow_list          = [4,2,2,2,2],
    contour_line_thickness_rainbow_list_policy   = "cycle",
    contour_line_style_rainbow_list              = ["solid","dot","dash","dash","dash"],
    contour_line_style_rainbow_list_policy       = "cycle",
    contour_threads                              = 1,
)

cream_coast = magics.mcoast(
    map_coastline_colour            = "grey",
    map_coastline_resolution        = "medium",
    map_coastline_thickness         = 2,
    map_coastline_land_shade        = "on",
    map_coastline_land_shade_colour = "cream",
    map_coastline_sea_shade         = "on",
    map_coastline_sea_shade_colour  = "sky",
    map_grid_line_style             = "dash",
    map_grid_colour                 = "grey"
)

magics.plot(projection, cream_coast, temperature, t_cont, legend)

# %% [markdown]
# ### Rainbow method to colour the isolines (list of colours and thickness)

# %%
t_cont = magics.mcont(
    contour_threads                            = 1,
    contour_label                              = "on",
    legend                                     = "on",
    contour_level_selection_type               = "count",
    contour_level_count                        = 41,
    contour_min_level                          = -20,
    contour_max_level                          = 20,
    contour_hilo                               = "on",
    contour_hilo_height                        = 0.4,
    contour_lo_colour                          = "cyan",
    contour_hi_colour                          = "red",
    contour_lo_max_value                       = 0,
    contour_hi_min_value                       = 0,    
    contour_line_thickess                      = 2,
    contour_line_colour_rainbow                = "on",
    contour_line_colour_rainbow_method         = "list",
    contour_line_colour_rainbow_colour_list    = ['#053061', '#0c3d73', '#134a86', '#1a5899', '#2166ac', 
                                                  '#2b71b2', '#347cb8', '#3c88bd', '#4393c3', '#5a9fca', 
                                                  '#6eacd1', '#80b8d7', '#92c5de', '#a2cde3', '#b2d5e7',
                                                  '#c2ddec', '#d1e5f0', '#dbe9f2', '#e4eef4', '#eef2f5', 
                                                  '#f7f7f7', '#f9f0eb', '#fbe9df', '#fce2d3', '#fddbc7', 
                                                  '#fccdb5', '#fac0a4', '#f7b293', '#f4a582', '#ed9474', 
                                                  '#e68367', '#de725a', '#d6604d', '#cd5144', '#c4413c', 
                                                  '#bb2f33', '#b2182b', '#9f1128', '#8c0a25', '#790422',
                                                  '#67001f'],
    contour_line_thickness_rainbow_list        = [4,1,1,1,1,2,1,1,1,1],
    contour_line_thickness_rainbow_list_policy = "cycle"
)


black_coast = magics.mcoast(
    map_coastline_colour            = "grey",
    map_coastline_resolution        = "medium",
    map_coastline_thickness         = 2,
    map_coastline_land_shade        = "on",
    map_coastline_land_shade_colour = "RGB(0.25,0.25,0.25)",
    map_coastline_sea_shade         = "on",
    map_coastline_sea_shade_colour  = "black",
    map_grid_line_style             = "dash",
    map_grid_colour                 = "grey"
)

magics.plot(projection, black_coast, temperature, t_cont, legend)

# %%
z_cont = magics.mcont( 
    contour_line_colour         = "black",
    contour_line_thickness      = 2,
    contour_highlight_colour    = "charcoal",
    contour_highlight_thickness = 6,
    contour_label               = "off",
    legend                      = "off",
    contour_level_selection_type= "interval",
    contour_interval            = 3,
    contour_highlight_style     = "chain_dash",
    contour_hilo                = "on",
    contour_reference_level     = 540,
    contour_hilo_height         = 0.4,
    contour_lo_colour           = "navy",
    contour_hi_colour           = "burgundy",
    contour_lo_max_value        = 560,
    contour_hi_min_value        = 530,
    )

europe = magics.mmap(
    subpage_map_library_area = "on",
    subpage_map_area_name    = "europe",
    page_id_line             = "off"
)

magics.plot(europe, coast, geopotential, z_cont)
